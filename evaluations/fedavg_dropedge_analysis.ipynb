# %% [markdown]
# # Effect of DropEdge over FedAvg + GCN over Subgraph FL with Non-overlapping Nodes

# %% [markdown]
# ## Cora Dataset

# %%
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir) 
from visualizer import *
#######################################################
current_dir = os.path.join('../../logs/', 'Cora_disjoint')
print('current_dir:', current_dir)
def create_info(name, logs, viz):
    return {'name': name, 'viz': viz,
        'logs': [os.path.join(current_dir, path) for path in logs]}
#######################################################
# %matplotlib inline
# Out:
# current_dir: ../../logs/Cora_disjoint

# %% [markdown]
# ### 5 Clients

# %%
clients = 'clients_5'
upto = 100
target_acc = 80
interval_rnd = 20
models = [
    create_info(
        name='FedAvg_NA', 
        logs=[
            f'{clients}/20230810_002130_fedavg_NA',
            f'{clients}/20230810_041235_fedavg_NA',
            f'{clients}/20230810_043700_fedavg_NA',
        ],
        viz={'color':'green', 'linewidth': 1, 'linestyle': '--', 'marker': 'o', 'markevery':interval_rnd, 'markersize':0}),
    create_info(
        name='FedAvg_DropEdge', 
        logs=[
            f'{clients}/20230809_234357_fedavg_DropEdge',
            f'{clients}/20230810_024225_fedavg_DropEdge',
            f'{clients}/20230810_031146_fedavg_DropEdge',
        ],
        viz={'color':'blue', 'linewidth': 1, 'linestyle': '--', 'marker': 'P', 'markevery':interval_rnd, 'markersize':0}),
]

plot_acc_over_round(models=models, upto=upto, opt={
    'plt_font_size': 22,
    'plt_line_width': 0.25,
    'plt_fig_size': (10,8),
    'plt_title': f'Performance on Disjoint Cora with {clients}',
    'plt_y_label': 'Local Accuracy (%)',
    'plt_x_label': 'Communication Rounds',
    'plt_x_interval': interval_rnd,
    'plt_background_grid': True,
    'plt_legend_opt': {'ncol':2, 'fontsize': 18, 'loc': 'lower right'},
    'plt_save': f'../plots/cora_{clients}.png'
})

summary(
    models = models,
    upto = upto,
    target_acc = target_acc,
    target_rnd = upto
)
# Out:
#              model Rnd @ Acc 80  Acc @ Rnd 100  Acc @ Best Val  \
# 0        FedAvg_NA          N/A          74.50           74.50
# 1  FedAvg_DropEdge          N/A          73.92           73.48
#
#    Std @ Best Val  Acc @ Best Val All  Std @ Best Val All  Processed Rnds
# 0            5.27               76.92                2.61             100
# 1            5.35               76.49                0.94             100

# %% [markdown]
# ### 10 Clients

# %%
clients = 'clients_10'
upto = 100
target_acc = 80
interval_rnd = 20
models = [
    create_info(
        name='FedAvg_NA', 
        logs=[
            f'{clients}/20230810_002424_fedavg_NA',
            f'{clients}/20230810_041213_fedavg_NA',
            f'{clients}/20230810_044546_fedavg_NA'
        ],
        viz={'color':'green', 'linewidth': 1, 'linestyle': '--', 'marker': 'o', 'markevery':interval_rnd, 'markersize':0}),
    create_info(
        name='FedAvg_DropEdge', 
        logs=[
            f'{clients}/20230809_234508_fedavg_DropEdge',
            f'{clients}/20230810_023954_fedavg_DropEdge',
            f'{clients}/20230810_032137_fedavg_DropEdge',
        ],
        viz={'color':'blue', 'linewidth': 1, 'linestyle': '--', 'marker': 'P', 'markevery':interval_rnd, 'markersize':0}),
]

plot_acc_over_round(models=models, upto=upto, opt={
    'plt_font_size': 22,
    'plt_line_width': 0.25,
    'plt_fig_size': (10,8),
    'plt_title': f'Performance on Disjoint Cora with {clients} ',
    'plt_y_label': 'Local Accuracy (%)',
    'plt_x_label': 'Communication Rounds',
    'plt_x_interval': interval_rnd,
    'plt_background_grid': True,
    'plt_legend_opt': {'ncol':2, 'fontsize': 18, 'loc': 'lower right'},
    'plt_save': f'../plots/cora_{clients}.png'
})

summary(
    models = models,
    upto = upto,
    target_acc = target_acc,
    target_rnd = upto
)
# Out:
#              model Rnd @ Acc 80  Acc @ Rnd 100  Acc @ Best Val  \
# 0        FedAvg_NA          N/A          68.26           68.55
# 1  FedAvg_DropEdge          N/A          68.49           68.49
#
#    Std @ Best Val  Acc @ Best Val All  Std @ Best Val All  Processed Rnds
# 0            1.51               68.63                1.62             100
# 1            0.70               68.48                0.69             100

# %% [markdown]
# ### 20 Clients

# %%
clients = 'clients_20'
upto = 100
target_acc = 80
interval_rnd = 20
models = [
    create_info(
        name='FedAvg_NA', 
        logs=[
            f'{clients}/20230810_020641_fedavg_NA',
        ],
        viz={'color':'green', 'linewidth': 1, 'linestyle': '--', 'marker': 'o', 'markevery':interval_rnd, 'markersize':0}),
    create_info(
        name='FedAvg_DropEdge', 
        logs=[
            f'{clients}/20230810_011403_fedavg_DropEdge',
        ],
        viz={'color':'blue', 'linewidth': 1, 'linestyle': '--', 'marker': 'P', 'markevery':interval_rnd, 'markersize':0}),
]

plot_acc_over_round(models=models, upto=upto, opt={
    'plt_font_size': 22,
    'plt_line_width': 0.25,
    'plt_fig_size': (10,8),
    'plt_title': f'Performance on Disjoint Cora with {clients} ',
    'plt_y_label': 'Local Accuracy (%)',
    'plt_x_label': 'Communication Rounds',
    'plt_x_interval': interval_rnd,
    'plt_background_grid': True,
    'plt_legend_opt': {'ncol':2, 'fontsize': 18, 'loc': 'lower right'},
    'plt_save': f'../plots/cora_{clients}.png'
})

summary(
    models = models,
    upto = upto,
    target_acc = target_acc,
    target_rnd = upto
)
# Out:
#              model Rnd @ Acc 80  Acc @ Rnd 100  Acc @ Best Val  \
# 0        FedAvg_NA          N/A          39.27           62.12
# 1  FedAvg_DropEdge          N/A          29.46           56.38
#
#    Std @ Best Val  Acc @ Best Val All  Std @ Best Val All  Processed Rnds
# 0             0.0               62.12                 0.0             100
# 1             0.0               56.38                 0.0             100

# %% [markdown]
# ## CiteSeer Dataset

# %% [markdown]
# ### 5 Clients

# %%
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir) 
from visualizer import *
#######################################################
current_dir = os.path.join('../../logs/', 'CiteSeer_disjoint')
print('current_dir:', current_dir)
def create_info(name, logs, viz):
    return {'name': name, 'viz': viz,
        'logs': [os.path.join(current_dir, path) for path in logs]}
#######################################################
# %matplotlib inline

# %%
clients = 'clients_5'
upto = 100
target_acc = 80
interval_rnd = 20
models = [
    create_info(
        name='FedAvg_NA', 
        logs=[
            f'{clients}/20230810_002424_fedavg_NA',
        ],
        viz={'color':'green', 'linewidth': 1, 'linestyle': '--', 'marker': 'o', 'markevery':interval_rnd, 'markersize':0}),
    create_info(
        name='FedAvg_DropEdge', 
        logs=[
            f'{clients}/20230809_234508_fedavg_DropEdge',
        ],
        viz={'color':'blue', 'linewidth': 1, 'linestyle': '--', 'marker': 'P', 'markevery':interval_rnd, 'markersize':0}),
]

plot_acc_over_round(models=models, upto=upto, opt={
    'plt_font_size': 22,
    'plt_line_width': 0.25,
    'plt_fig_size': (10,8),
    'plt_title': f'Performance on Disjoint Cora with {clients} ',
    'plt_y_label': 'Local Accuracy (%)',
    'plt_x_label': 'Communication Rounds',
    'plt_x_interval': interval_rnd,
    'plt_background_grid': True,
    'plt_legend_opt': {'ncol':2, 'fontsize': 18, 'loc': 'lower right'},
    'plt_save': f'../plots/citeseer_{clients}.png'
})

summary(
    models = models,
    upto = upto,
    target_acc = target_acc,
    target_rnd = upto
)

# %% [markdown]
# ### 10 Clients

# %%
clients = 'clients_10'
upto = 100
target_acc = 80
interval_rnd = 20
models = [
    create_info(
        name='FedAvg_NA', 
        logs=[
            f'{clients}/20230810_002424_fedavg_NA',
        ],
        viz={'color':'green', 'linewidth': 1, 'linestyle': '--', 'marker': 'o', 'markevery':interval_rnd, 'markersize':0}),
    create_info(
        name='FedAvg_DropEdge', 
        logs=[
            f'{clients}/20230809_234508_fedavg_DropEdge',
        ],
        viz={'color':'blue', 'linewidth': 1, 'linestyle': '--', 'marker': 'P', 'markevery':interval_rnd, 'markersize':0}),
]

plot_acc_over_round(models=models, upto=upto, opt={
    'plt_font_size': 22,
    'plt_line_width': 0.25,
    'plt_fig_size': (10,8),
    'plt_title': f'Performance on Disjoint Cora with {clients} ',
    'plt_y_label': 'Local Accuracy (%)',
    'plt_x_label': 'Communication Rounds',
    'plt_x_interval': interval_rnd,
    'plt_background_grid': True,
    'plt_legend_opt': {'ncol':2, 'fontsize': 18, 'loc': 'lower right'},
    'plt_save': f'../plots/citeseer_{clients}.png'
})

summary(
    models = models,
    upto = upto,
    target_acc = target_acc,
    target_rnd = upto
)

# %% [markdown]
# ### 20 Clients

# %%
clients = 'clients_20'
upto = 100
target_acc = 80
interval_rnd = 20
models = [
    create_info(
        name='FedAvg_NA', 
        logs=[
            f'{clients}/20230810_002424_fedavg_NA',
        ],
        viz={'color':'green', 'linewidth': 1, 'linestyle': '--', 'marker': 'o', 'markevery':interval_rnd, 'markersize':0}),
    create_info(
        name='FedAvg_DropEdge', 
        logs=[
            f'{clients}/20230809_234508_fedavg_DropEdge',
        ],
        viz={'color':'blue', 'linewidth': 1, 'linestyle': '--', 'marker': 'P', 'markevery':interval_rnd, 'markersize':0}),
]

plot_acc_over_round(models=models, upto=upto, opt={
    'plt_font_size': 22,
    'plt_line_width': 0.25,
    'plt_fig_size': (10,8),
    'plt_title': f'Performance on Disjoint Cora with {clients} ',
    'plt_y_label': 'Local Accuracy (%)',
    'plt_x_label': 'Communication Rounds',
    'plt_x_interval': interval_rnd,
    'plt_background_grid': True,
    'plt_legend_opt': {'ncol':2, 'fontsize': 18, 'loc': 'lower right'},
    'plt_save': f'../plots/citeseer_{clients}.png'
})

summary(
    models = models,
    upto = upto,
    target_acc = target_acc,
    target_rnd = upto
)

# %% [markdown]
# ## PubMed Dataset

# %% [markdown]
# # Effect of DropEdge over FedAvg + GCN over Subgraph FL with Overlapping Nodes
#
# TBD

# %%
import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir) 
from visualizer import *
#######################################################
current_dir = os.path.join('../../logs/', 'Cora_overlapping')
print('current_dir:', current_dir)
def create_info(name, logs, viz):
    return {'name': name, 'viz': viz,
        'logs': [os.path.join(current_dir, path) for path in logs]}
#######################################################
# %matplotlib inline
# Out:
# current_dir: ../../logs/Cora_overlapping

# %%
clients = 'clients_30'
upto = 100
target_acc = 80
interval_rnd = 20
models = [
    create_info(
        name='FedAvg', 
        logs=[
            f'{clients}/20230702_141324_fedavg',
        ],
        viz={'color':'green', 'linewidth': 1, 'linestyle': '--', 'marker': 'o', 'markevery':interval_rnd, 'markersize':0}),
    create_info(
        name='FED-PUB', 
        logs=[
            f'{clients}/20230702_150505_fedpub',
        ],
        viz={'color':'blue', 'linewidth': 1, 'linestyle': '--', 'marker': 'P', 'markevery':interval_rnd, 'markersize':0}),
]

plot_acc_over_round(models=models, upto=upto, opt={
    'plt_font_size': 22,
    'plt_line_width': 0.25,
    'plt_fig_size': (10,8),
    'plt_title': f'Performance on Cora with {clients}',
    'plt_y_label': 'Local Accuracy (%)',
    'plt_x_label': 'Communication Rounds',
    'plt_x_interval': interval_rnd,
    'plt_background_grid': True,
    'plt_legend_opt': {'ncol':2, 'fontsize': 18, 'loc': 'lower right'},
    'plt_save': f'./plots/cora_{clients}.png'
})

summary(
    models = models,
    upto = upto,
    target_acc = target_acc,
    target_rnd = upto
)
# Out:
#      model Rnd @ Acc 80  Acc @ Rnd 100  Acc @ Best Val  Std @ Best Val  \
# 0   FedAvg          N/A          54.44           54.44             0.0
# 1  FED-PUB          N/A          75.79           75.70             0.0
#
#    Acc @ Best Val All  Std @ Best Val All  Processed Rnds
# 0               54.44                 0.0             100
# 1               75.70                 0.0             100
